# %% [markdown]
# Run the next code block. There will be two separate authentications needed. The first will download all extra files from the CIS580 shared drive files. The second connects your google drive to save files to 'cis580-2019-hw6'

# %%
# bootstrap environment into place
from google.colab import auth
auth.authenticate_user()

from googleapiclient.discovery import build
drive_service = build('drive', 'v3')

import io
import os
from googleapiclient.http import MediaIoBaseDownload

def download_file(fn, file_id):
    request = drive_service.files().get_media(fileId=file_id)
    downloaded = io.BytesIO()
    downloader = MediaIoBaseDownload(downloaded, request)
    done = False
    while done is False:
        # _ is a placeholder for a progress object that we ignore.
        # (Our file is small, so we skip reporting progress.)
        _, done = downloader.next_chunk()
    
    downloaded.seek(0)

    folder = fn.split('/')
    if len(folder) > 1:
        os.makedirs(folder[0], exist_ok=True)

    with open(fn, 'wb') as f:
        f.write(downloaded.read())

id_to_fn = {
        '1PIhom4rR_a_vm-zCt_1rYKbz8sd43Gel': "data/images.npz",
        '1IOxsTUF-MgmDRp3-0jPMJ-qo8yLZFCez': "data/train_data.npz",
        '1ZPRZoiuQVwWm88dWB4kWTBTtSQKBaDxs': "data/valid_data.npz",
        '1rJgn9NHdnwToyIERWbS8g_gZu19wAkkd': "data/kpt.npy",
        '1noGbThisv1HOi87dG66AfgQzpIv0o1y6': "data/misc_data.npz",
        '1Jp94eNQyXlTBYhqFFksbwRRl9VOGLAYT': "utils/__init__.py",
        '1UCCx78ZFL-BxsIScl0YkaLSRjw6Umliu': "utils/pose_utils.py",
        '1lV3oSGB2ygBj0vF2zaj_FKVaExz4-loi': "utils/plotting.py",
        '1td00aFXojVptGMz1XRTuVWSdpAHYi4lt': "utils/train_options.py",
        '18NNIqvS5-GB9xGWJX0wjHeC_RaaoKnWz': "hourglass.py",
        '1mJS9HFhDoUR1XGxRNQm2e-j4WZQn7Zhl': "dataset.py",
           }

# download all files into the vm
for fid, fn in id_to_fn.items():
    download_file(fn, fid)

# mount the user's google drive into the system
from google.colab import drive
drive.mount('/content/gdrive')
# create folder to write data to
os.makedirs('/content/gdrive/My Drive/cis580-2019-hw6', exist_ok=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# The next code block handles the external library imports.

# %%
from __future__ import division
from __future__ import print_function

import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import make_grid

from hourglass import hg

from dataset import Dataset
from dataset import RandomFlipLR, RandomRescaleBB, RandomRotation,\
                    CropAndPad, LocsToHeatmaps,\
                    ToTensor, Normalize, Denormalize
from utils import TrainOptions, PoseUtils

from tqdm import tqdm
from PIL import Image
import os
from time import time
import numpy as np

# %% [markdown]
# Step 1) The Trainer class contains two locations where you must implement the training step and the test step as specified in the accompanying PDF

# %%
class Trainer(object):

    def __init__(self, options):
        self.options = options
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        train_transform_list = []
        train_transform_list.append(RandomRescaleBB(0.8, 1.2))
        train_transform_list.append(RandomFlipLR())
        train_transform_list.append(RandomRotation(degrees=options.degrees))
        train_transform_list.append(CropAndPad(out_size=(options.crop_size, options.crop_size)))
        train_transform_list.append(LocsToHeatmaps(out_size=(options.heatmap_size, options.heatmap_size)))
        train_transform_list.append(ToTensor())
        train_transform_list.append(Normalize())
        test_transform_list = [CropAndPad(out_size=(options.crop_size, options.crop_size))]
        test_transform_list.append(LocsToHeatmaps(out_size=(options.heatmap_size, options.heatmap_size)))
        test_transform_list.append(ToTensor())
        test_transform_list.append(Normalize())
        self.train_ds = Dataset(is_train=True, transform=transforms.Compose(train_transform_list))
        self.test_ds = Dataset(is_train=False, transform=transforms.Compose(test_transform_list))

        self.model = hg(num_stacks=options.num_stacks, num_blocks=options.num_blocks, num_classes=options.num_classes).to(self.device)
        # define loss function and optimizer
        self.heatmap_loss = torch.nn.MSELoss().to(self.device) # for Global loss
        self.optimizer = torch.optim.RMSprop(self.model.parameters(),
                                             lr = options.lr)


        self.pose_utils = PoseUtils(detection_thresh=options.detection_thresh, dist_thresh=options.dist_thresh)

        self.train_data_loader = DataLoader(self.train_ds, batch_size=options.batch_size,
                                            num_workers=options.num_workers,
                                            pin_memory=True,
                                            shuffle=True)
        self.test_data_loader = DataLoader(self.test_ds, batch_size=options.test_batch_size,
                                           num_workers=options.num_workers,
                                           pin_memory=True,
                                           shuffle=True)

        self.summary_iters = []
        self.losses = []
        self.pcks = []

    def train(self):
        self.total_step_count = 0
        start_time = time()
        for epoch in range(1,self.options.num_epochs+1):
            elapsed_time = time() - start_time
            seconds_per_epoch = elapsed_time / epoch
            remaining_time = (self.options.num_epochs - epoch) * seconds_per_epoch

            print("Epoch %d/%d - Elapsed Time %f - Remaining Time %f" %
                    (epoch, self.options.num_epochs,
                        elapsed_time, remaining_time))

            for step, batch in enumerate(self.train_data_loader):
                self.model.train()
                batch = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v for k,v in batch.items()}
                """
                ADD YOUR CODE FOR THE TRAINING STEP HERE
                You have to name the output of your neural network pred_heatmap_list
                This list contains the output heatmaps for each stack of the Stacked Hourglass model
                Since we are using only 1 stack in this homework, pred_heatmap_list will contain only 1 tensor
                """
                ##
                self.optimizer.zero_grad()

                pred_heatmap_list = self.model(batch['image'] );
                pred_heatmap = pred_heatmap_list[-1]
                
                loss = self.heatmap_loss(pred_heatmap, batch['keypoint_heatmaps'] )
                loss.backward()
                
                ##
                self.optimizer.step()
                self.total_step_count += 1
                if self.total_step_count % self.options.summary_steps == 0:
                    self.save_summaries(batch, pred_heatmap_list[-1].detach(), loss.detach(), mode='train')
                if self.total_step_count % self.options.test_steps == 0:
                    self.model.eval()
                    batch = next(iter(self.test_data_loader))
                    batch = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v for k,v in batch.items()}
                    """
                    ADD YOUR CODE FOR THE TEST STEP HERE
                    What you have to do is to perform a forward pass and record the loss and the output
                    """
                    ##
                    with torch.no_grad():
                      pred_heatmap_list = self.model(batch['image'])
                      pred_heatmap = pred_heatmap_list[-1]
                
                      loss =self.heatmap_loss(pred_heatmap, batch['keypoint_heatmaps'])
                    ##
                      self.save_summaries(batch, pred_heatmap_list[-1], loss, mode='test')

        checkpoint = {'model': self.model.state_dict()}
        torch.save(checkpoint, '/content/gdrive/My Drive/cis580-2019-hw6/model_checkpoint.pt')

    def save_summaries(self, batch, pred_heatmaps, loss, mode='train'):
        gt_heatmaps = batch['keypoint_heatmaps'].to(self.device)
        pck = self.pose_utils.pck(gt_heatmaps, pred_heatmaps)

        batch = Denormalize()(batch)
        images = batch['image']

        gt_image_keypoints, pred_image_keypoints = self.pose_utils.draw_keypoints_with_labels(images, gt_heatmaps, pred_heatmaps)

        gt_image_keypoints_grid = make_grid(gt_image_keypoints, pad_value=1, nrow=3)
        pred_image_keypoints_grid = make_grid(pred_image_keypoints, pad_value=1, nrow=3)

        pred_heatmaps_grid = make_grid(pred_heatmaps[0,:,:,:].unsqueeze(0).transpose(0,1), pad_value=1, nrow=5)
        pred_heatmaps_grid[pred_heatmaps_grid > 1] = 1
        pred_heatmaps_grid[pred_heatmaps_grid < 0] = 0

        self.losses.append(loss)
        self.pcks.append(pck)
        self.summary_iters.append(self.total_step_count)

        folder = '/content/gdrive/My Drive/cis580-2019-hw6/logs/%d' % self.total_step_count
        os.makedirs(folder, exist_ok=True)

        gt_ikg = Image.fromarray((gt_image_keypoints_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))
        pred_ikg = Image.fromarray((pred_image_keypoints_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))
        pred_hg = Image.fromarray((pred_heatmaps_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))

        gt_ikg.save(os.path.join(folder, mode + '_gt_image_keypoints.jpg'))
        pred_ikg.save(os.path.join(folder, mode + '_pred_image_keypoints.jpg'))
        pred_hg.save(os.path.join(folder, mode + '_pred_heatmaps.jpg'))

# %% [markdown]
# The next block will start the training process. Be sure to run the above block first every time you want to test changes to the code.

# %%
options = TrainOptions().parse_args(["--name=gascan",
                                     "--summary_steps=200",
                                     "--num_epochs=400",
                                     "--test_steps=1000"])
trainer = Trainer(options)
trainer.train()
# Out:
# Epoch 1/400 - Elapsed Time 0.000003 - Remaining Time 0.001142
# Epoch 2/400 - Elapsed Time 4.913565 - Remaining Time 977.799419
# Epoch 3/400 - Elapsed Time 10.370289 - Remaining Time 1372.334923
# Epoch 4/400 - Elapsed Time 15.477810 - Remaining Time 1532.303228
# Epoch 5/400 - Elapsed Time 20.336117 - Remaining Time 1606.553226
# Epoch 6/400 - Elapsed Time 25.567388 - Remaining Time 1678.925149
# Epoch 7/400 - Elapsed Time 30.669117 - Remaining Time 1721.851866
# Epoch 8/400 - Elapsed Time 35.565544 - Remaining Time 1742.711674
# Epoch 9/400 - Elapsed Time 40.441035 - Remaining Time 1756.938279
# Epoch 10/400 - Elapsed Time 45.265897 - Remaining Time 1765.369966
# Epoch 11/400 - Elapsed Time 50.496872 - Remaining Time 1785.753009
# Epoch 12/400 - Elapsed Time 58.667831 - Remaining Time 1896.926526
# Epoch 13/400 - Elapsed Time 63.673984 - Remaining Time 1895.525511
# Epoch 14/400 - Elapsed Time 68.638459 - Remaining Time 1892.460369
# Epoch 15/400 - Elapsed Time 73.589887 - Remaining Time 1888.807091
# Epoch 16/400 - Elapsed Time 78.517382 - Remaining Time 1884.417177
# Epoch 17/400 - Elapsed Time 83.465684 - Remaining Time 1880.432762
# Epoch 18/400 - Elapsed Time 88.961655 - Remaining Time 1887.964010
# Epoch 19/400 - Elapsed Time 94.547138 - Remaining Time 1895.918920
# Epoch 139/400 - Elapsed Time 758.121775 - Remaining Time 1423.523621
# Epoch 140/400 - Elapsed Time 763.747971 - Remaining Time 1418.389088
# Epoch 141/400 - Elapsed Time 769.363087 - Remaining Time 1413.227231
# Epoch 142/400 - Elapsed Time 774.614470 - Remaining Time 1407.398121
# Epoch 143/400 - Elapsed Time 779.649779 - Remaining Time 1401.188763
# Epoch 144/400 - Elapsed Time 784.719345 - Remaining Time 1395.056614
# Epoch 145/400 - Elapsed Time 789.891099 - Remaining Time 1389.118830
# Epoch 146/400 - Elapsed Time 795.080509 - Remaining Time 1383.222255
# Epoch 147/400 - Elapsed Time 800.084303 - Remaining Time 1377.015841
# Epoch 148/400 - Elapsed Time 805.257405 - Remaining Time 1371.113959
# Epoch 149/400 - Elapsed Time 813.615754 - Remaining Time 1370.587613
# Epoch 150/400 - Elapsed Time 819.089648 - Remaining Time 1365.149413
# Epoch 151/400 - Elapsed Time 824.219755 - Remaining Time 1359.143834
# Epoch 152/400 - Elapsed Time 829.258392 - Remaining Time 1353.000534
# Epoch 153/400 - Elapsed Time 834.394646 - Remaining Time 1347.029266
# Epoch 154/400 - Elapsed Time 839.562586 - Remaining Time 1341.119455
# Epoch 155/400 - Elapsed Time 844.552151 - Remaining Time 1334.937272
# Epoch 156/400 - Elapsed Time 849.574298 - Remaining Time 1328.821338
# Epoch 157/400 - Elapsed Time 854.597811 - Remaining Time 1322.721453
# Epoch 158/400 - Elapsed Time 859.667023 - Remaining Time 1316.705188
# Epoch 159/400 - Elapsed Time 871.256886 - Remaining Time 1320.584337
# Epoch 160/400 - Elapsed Time 876.298336 - Remaining Time 1314.447503
# Epoch 161/400 - Elapsed Time 881.466793 - Remaining Time 1308.512817
# Epoch 162/400 - Elapsed Time 886.701623 - Remaining Time 1302.685100
# Epoch 163/400 - Elapsed Time 892.380338 - Remaining Time 1297.510062
# Epoch 164/400 - Elapsed Time 898.077268 - Remaining Time 1292.355093
# Epoch 165/400 - Elapsed Time 903.188895 - Remaining Time 1286.359941
# Epoch 166/400 - Elapsed Time 908.218419 - Remaining Time 1280.259700
# Epoch 167/400 - Elapsed Time 913.355598 - Remaining Time 1274.322482
# Epoch 168/400 - Elapsed Time 918.539852 - Remaining Time 1268.459796
# Epoch 169/400 - Elapsed Time 923.606982 - Remaining Time 1262.445047
# Epoch 170/400 - Elapsed Time 931.151825 - Remaining Time 1259.793646
# Epoch 171/400 - Elapsed Time 936.568159 - Remaining Time 1254.234552
# Epoch 172/400 - Elapsed Time 941.665728 - Remaining Time 1248.254569
# Epoch 173/400 - Elapsed Time 946.805771 - Remaining Time 1242.340520
# Epoch 174/400 - Elapsed Time 951.774470 - Remaining Time 1236.212817
# Epoch 175/400 - Elapsed Time 956.942326 - Remaining Time 1230.354419
# Epoch 176/400 - Elapsed Time 961.951577 - Remaining Time 1224.302008
# Epoch 177/400 - Elapsed Time 967.080106 - Remaining Time 1218.411659
# Epoch 216/400 - Elapsed Time 1184.357800 - Remaining Time 1008.897385
# Epoch 217/400 - Elapsed Time 1189.423172 - Remaining Time 1003.061937
# Epoch 218/400 - Elapsed Time 1194.620431 - Remaining Time 997.343663
# Epoch 219/400 - Elapsed Time 1199.596403 - Remaining Time 991.447255
# Epoch 220/400 - Elapsed Time 1204.610331 - Remaining Time 985.590270
# Epoch 221/400 - Elapsed Time 1209.666651 - Remaining Time 979.775252
# Epoch 222/400 - Elapsed Time 1215.309452 - Remaining Time 974.437308
# Epoch 223/400 - Elapsed Time 1223.443062 - Remaining Time 971.073641
# Epoch 224/400 - Elapsed Time 1228.522103 - Remaining Time 965.267367
# Epoch 225/400 - Elapsed Time 1233.553215 - Remaining Time 959.430278
# Epoch 226/400 - Elapsed Time 1238.672197 - Remaining Time 953.667974
# Epoch 227/400 - Elapsed Time 1243.625649 - Remaining Time 947.785186
# Epoch 228/400 - Elapsed Time 1248.756633 - Remaining Time 942.044478
# Epoch 229/400 - Elapsed Time 1253.861394 - Remaining Time 936.289512
# Epoch 230/400 - Elapsed Time 1258.842078 - Remaining Time 930.448493
# Epoch 231/400 - Elapsed Time 1263.857132 - Remaining Time 924.640066
# Epoch 232/400 - Elapsed Time 1269.012910 - Remaining Time 918.940383
# Epoch 233/400 - Elapsed Time 1276.478186 - Remaining Time 914.900674
# Epoch 234/400 - Elapsed Time 1281.603695 - Remaining Time 909.171852
# Epoch 235/400 - Elapsed Time 1286.896319 - Remaining Time 903.565501
# Epoch 236/400 - Elapsed Time 1292.210457 - Remaining Time 897.976758
# Epoch 237/400 - Elapsed Time 1298.016325 - Remaining Time 892.728527
# Epoch 238/400 - Elapsed Time 1303.294947 - Remaining Time 887.116729
# Epoch 239/400 - Elapsed Time 1308.313542 - Remaining Time 881.332553
# Epoch 240/400 - Elapsed Time 1313.357064 - Remaining Time 875.571376
# Epoch 241/400 - Elapsed Time 1318.403795 - Remaining Time 869.818271
# Epoch 242/400 - Elapsed Time 1323.349254 - Remaining Time 864.004885
# Epoch 243/400 - Elapsed Time 1328.612608 - Remaining Time 858.404031
# Epoch 244/400 - Elapsed Time 1336.499208 - Remaining Time 854.483100
# Epoch 245/400 - Elapsed Time 1341.766228 - Remaining Time 848.872512
# Epoch 246/400 - Elapsed Time 1347.009033 - Remaining Time 843.249557
# Epoch 247/400 - Elapsed Time 1352.099672 - Remaining Time 837.535424
# Epoch 248/400 - Elapsed Time 1357.221773 - Remaining Time 831.845603
# Epoch 249/400 - Elapsed Time 1362.440864 - Remaining Time 826.219158
# Epoch 250/400 - Elapsed Time 1367.622189 - Remaining Time 820.573314
# Epoch 251/400 - Elapsed Time 1372.942078 - Remaining Time 815.013425
# Epoch 252/400 - Elapsed Time 1378.554976 - Remaining Time 809.627526
# Epoch 253/400 - Elapsed Time 1384.251288 - Remaining Time 804.288298
# Epoch 254/400 - Elapsed Time 1392.539392 - Remaining Time 800.436028
# Epoch 255/400 - Elapsed Time 1397.684124 - Remaining Time 794.761561
# Epoch 256/400 - Elapsed Time 1402.735922 - Remaining Time 789.038956
# Epoch 257/400 - Elapsed Time 1407.718251 - Remaining Time 783.282918
# Epoch 258/400 - Elapsed Time 1412.910691 - Remaining Time 777.648520
# Epoch 259/400 - Elapsed Time 1418.234220 - Remaining Time 772.088900
# Epoch 260/400 - Elapsed Time 1423.405182 - Remaining Time 766.448944
# Epoch 261/400 - Elapsed Time 1428.373091 - Remaining Time 760.704443
# Epoch 262/400 - Elapsed Time 1433.448345 - Remaining Time 755.022411
# Epoch 263/400 - Elapsed Time 1438.478087 - Remaining Time 749.321285
# Epoch 264/400 - Elapsed Time 1443.545773 - Remaining Time 743.644792
# Epoch 265/400 - Elapsed Time 1455.718048 - Remaining Time 741.592213
# Epoch 266/400 - Elapsed Time 1461.445436 - Remaining Time 736.216874
# Epoch 267/400 - Elapsed Time 1466.468831 - Remaining Time 730.488219
# Epoch 268/400 - Elapsed Time 1471.471165 - Remaining Time 724.754454
# Epoch 269/400 - Elapsed Time 1476.706197 - Remaining Time 719.139449
# Epoch 270/400 - Elapsed Time 1482.422144 - Remaining Time 713.758810
# Epoch 271/400 - Elapsed Time 1487.941354 - Remaining Time 708.282047
# Epoch 272/400 - Elapsed Time 1493.533018 - Remaining Time 702.839067
# Epoch 273/400 - Elapsed Time 1498.502652 - Remaining Time 697.105629
# Epoch 274/400 - Elapsed Time 1503.722910 - Remaining Time 691.493017
# Epoch 275/400 - Elapsed Time 1511.275294 - Remaining Time 686.943315
# Epoch 276/400 - Elapsed Time 1516.446645 - Remaining Time 681.302116
# Epoch 277/400 - Elapsed Time 1521.680035 - Remaining Time 675.691857
# Epoch 278/400 - Elapsed Time 1526.631862 - Remaining Time 669.960745
# Epoch 279/400 - Elapsed Time 1531.682636 - Remaining Time 664.278132
# Epoch 280/400 - Elapsed Time 1537.491868 - Remaining Time 658.925086
# Epoch 281/400 - Elapsed Time 1543.066671 - Remaining Time 653.469515
# Epoch 282/400 - Elapsed Time 1548.162213 - Remaining Time 647.812557
# Epoch 283/400 - Elapsed Time 1553.197509 - Remaining Time 642.134659
# Epoch 284/400 - Elapsed Time 1558.206519 - Remaining Time 636.450550
# Epoch 285/400 - Elapsed Time 1563.300187 - Remaining Time 630.805339
# Epoch 286/400 - Elapsed Time 1571.131909 - Remaining Time 626.255376
# Epoch 287/400 - Elapsed Time 1576.188146 - Remaining Time 620.589758
# Epoch 288/400 - Elapsed Time 1581.129551 - Remaining Time 614.883714
# Epoch 289/400 - Elapsed Time 1586.092234 - Remaining Time 609.191135
# Epoch 290/400 - Elapsed Time 1591.373075 - Remaining Time 603.624270
# Epoch 291/400 - Elapsed Time 1596.457249 - Remaining Time 597.985705
# Epoch 292/400 - Elapsed Time 1601.666622 - Remaining Time 592.397244
# Epoch 293/400 - Elapsed Time 1606.809260 - Remaining Time 586.786999
# Epoch 294/400 - Elapsed Time 1611.980671 - Remaining Time 581.190310
# Epoch 295/400 - Elapsed Time 1617.771155 - Remaining Time 575.816852
# Epoch 296/400 - Elapsed Time 1625.657887 - Remaining Time 571.177096
# Epoch 297/400 - Elapsed Time 1630.672166 - Remaining Time 565.519303
# Epoch 298/400 - Elapsed Time 1635.718938 - Remaining Time 559.876952
# Epoch 299/400 - Elapsed Time 1640.733653 - Remaining Time 554.227756
# Epoch 300/400 - Elapsed Time 1645.834595 - Remaining Time 548.611532
# Epoch 301/400 - Elapsed Time 1650.999204 - Remaining Time 543.019672
# Epoch 302/400 - Elapsed Time 1656.017140 - Remaining Time 537.383045
# Epoch 303/400 - Elapsed Time 1661.052192 - Remaining Time 531.755982
# Epoch 304/400 - Elapsed Time 1666.006848 - Remaining Time 526.107426
# Epoch 305/400 - Elapsed Time 1671.020286 - Remaining Time 520.481728
# Epoch 306/400 - Elapsed Time 1675.982322 - Remaining Time 514.844243
# Epoch 307/400 - Elapsed Time 1683.690008 - Remaining Time 510.042901
# Epoch 308/400 - Elapsed Time 1688.765101 - Remaining Time 504.436329
# Epoch 309/400 - Elapsed Time 1694.328817 - Remaining Time 498.977095
# Epoch 310/400 - Elapsed Time 1700.068868 - Remaining Time 493.568381
# Epoch 311/400 - Elapsed Time 1705.287033 - Remaining Time 488.008186
# Epoch 312/400 - Elapsed Time 1710.358495 - Remaining Time 482.408806
# Epoch 313/400 - Elapsed Time 1715.430382 - Remaining Time 476.812918
# Epoch 314/400 - Elapsed Time 1720.650606 - Remaining Time 471.260994
# Epoch 315/400 - Elapsed Time 1726.394253 - Remaining Time 465.852418
# Epoch 316/400 - Elapsed Time 1731.503468 - Remaining Time 460.273074
# Epoch 317/400 - Elapsed Time 1743.503117 - Remaining Time 456.500816
# Epoch 318/400 - Elapsed Time 1748.508537 - Remaining Time 450.873270
# Epoch 319/400 - Elapsed Time 1753.888268 - Remaining Time 445.344670
# Epoch 320/400 - Elapsed Time 1758.889448 - Remaining Time 439.722362
# Epoch 321/400 - Elapsed Time 1763.970747 - Remaining Time 434.123642
# Epoch 322/400 - Elapsed Time 1768.976047 - Remaining Time 428.509726
# Epoch 323/400 - Elapsed Time 1774.266808 - Remaining Time 422.967629
# Epoch 324/400 - Elapsed Time 1779.937237 - Remaining Time 417.516142
# Epoch 325/400 - Elapsed Time 1785.227556 - Remaining Time 411.975590
# Epoch 326/400 - Elapsed Time 1790.399425 - Remaining Time 406.409685
# Epoch 327/400 - Elapsed Time 1795.560708 - Remaining Time 400.843828
# Epoch 328/400 - Elapsed Time 1803.252333 - Remaining Time 395.835878
# Epoch 329/400 - Elapsed Time 1808.538291 - Remaining Time 390.292458
# Epoch 330/400 - Elapsed Time 1813.602111 - Remaining Time 384.703478
# Epoch 331/400 - Elapsed Time 1818.826164 - Remaining Time 379.151073
# Epoch 332/400 - Elapsed Time 1823.852544 - Remaining Time 373.560160
# Epoch 333/400 - Elapsed Time 1828.907167 - Remaining Time 367.978319
# Epoch 334/400 - Elapsed Time 1834.060122 - Remaining Time 362.419066
# Epoch 335/400 - Elapsed Time 1839.523201 - Remaining Time 356.922412
# Epoch 336/400 - Elapsed Time 1844.543755 - Remaining Time 351.341668
# Epoch 337/400 - Elapsed Time 1849.574686 - Remaining Time 345.766188
# Epoch 338/400 - Elapsed Time 1857.491416 - Remaining Time 340.723277
# Epoch 339/400 - Elapsed Time 1863.122795 - Remaining Time 335.252184
# Epoch 340/400 - Elapsed Time 1868.346898 - Remaining Time 329.708276
# Epoch 341/400 - Elapsed Time 1873.582756 - Remaining Time 324.168277
# Epoch 342/400 - Elapsed Time 1878.608281 - Remaining Time 318.594387
# Epoch 343/400 - Elapsed Time 1883.658383 - Remaining Time 313.027778
# Epoch 344/400 - Elapsed Time 1888.735892 - Remaining Time 307.468634
# Epoch 345/400 - Elapsed Time 1893.913115 - Remaining Time 301.928178
# Epoch 346/400 - Elapsed Time 1898.943971 - Remaining Time 296.366978
# Epoch 347/400 - Elapsed Time 1904.096017 - Remaining Time 290.827346
# Epoch 348/400 - Elapsed Time 1909.306849 - Remaining Time 285.298725
# Epoch 349/400 - Elapsed Time 1917.049009 - Remaining Time 280.141832
# Epoch 350/400 - Elapsed Time 1922.147517 - Remaining Time 274.592502
# Epoch 351/400 - Elapsed Time 1927.246585 - Remaining Time 269.045820
# Epoch 352/400 - Elapsed Time 1932.311575 - Remaining Time 263.497033
# Epoch 353/400 - Elapsed Time 1937.982040 - Remaining Time 258.031603
# Epoch 354/400 - Elapsed Time 1943.563583 - Remaining Time 252.553460
# Epoch 355/400 - Elapsed Time 1948.636864 - Remaining Time 247.010307
# Epoch 356/400 - Elapsed Time 1953.760672 - Remaining Time 241.476038
# Epoch 357/400 - Elapsed Time 1958.897384 - Remaining Time 235.945623
# Epoch 358/400 - Elapsed Time 1963.964759 - Remaining Time 230.409273
# Epoch 359/400 - Elapsed Time 1971.620904 - Remaining Time 225.171190
# Epoch 360/400 - Elapsed Time 1976.728375 - Remaining Time 219.636486
# Epoch 361/400 - Elapsed Time 1981.957818 - Remaining Time 214.117327
# Epoch 362/400 - Elapsed Time 1987.053011 - Remaining Time 208.585675
# Epoch 363/400 - Elapsed Time 1992.107174 - Remaining Time 203.052246
# Epoch 364/400 - Elapsed Time 1997.218218 - Remaining Time 197.527076
# Epoch 365/400 - Elapsed Time 2002.445136 - Remaining Time 192.015287
# Epoch 366/400 - Elapsed Time 2008.312865 - Remaining Time 186.564583
# Epoch 367/400 - Elapsed Time 2013.895541 - Remaining Time 181.085975
# Epoch 368/400 - Elapsed Time 2019.629603 - Remaining Time 175.619965
# Epoch 369/400 - Elapsed Time 2025.079607 - Remaining Time 170.128639
# Epoch 370/400 - Elapsed Time 2037.657452 - Remaining Time 165.215469
# Epoch 371/400 - Elapsed Time 2042.706881 - Remaining Time 159.672506
# Epoch 372/400 - Elapsed Time 2047.864982 - Remaining Time 154.140375
# Epoch 373/400 - Elapsed Time 2053.246031 - Remaining Time 148.626388
# Epoch 374/400 - Elapsed Time 2058.414253 - Remaining Time 143.098317
# Epoch 375/400 - Elapsed Time 2063.545137 - Remaining Time 137.569676
# Epoch 376/400 - Elapsed Time 2068.606382 - Remaining Time 132.038705
# Epoch 377/400 - Elapsed Time 2073.816038 - Remaining Time 126.519281
# Epoch 378/400 - Elapsed Time 2078.899421 - Remaining Time 120.994146
# Epoch 379/400 - Elapsed Time 2084.270687 - Remaining Time 115.487294
# Epoch 380/400 - Elapsed Time 2092.208330 - Remaining Time 110.116228
# Epoch 381/400 - Elapsed Time 2097.734362 - Remaining Time 104.611425
# Epoch 382/400 - Elapsed Time 2103.566403 - Remaining Time 99.120930
# Epoch 383/400 - Elapsed Time 2108.662120 - Remaining Time 93.595969
# Epoch 384/400 - Elapsed Time 2113.705130 - Remaining Time 88.071047
# Epoch 385/400 - Elapsed Time 2118.795957 - Remaining Time 82.550492
# Epoch 386/400 - Elapsed Time 2123.895899 - Remaining Time 77.032494
# Epoch 387/400 - Elapsed Time 2129.119950 - Remaining Time 71.520825
# Epoch 388/400 - Elapsed Time 2134.198480 - Remaining Time 66.006139
# Epoch 389/400 - Elapsed Time 2139.249674 - Remaining Time 60.492921
# Epoch 390/400 - Elapsed Time 2144.327784 - Remaining Time 54.982764
# Epoch 391/400 - Elapsed Time 2151.804057 - Remaining Time 49.530017
# Epoch 392/400 - Elapsed Time 2157.110280 - Remaining Time 44.022659
# Epoch 393/400 - Elapsed Time 2162.564623 - Remaining Time 38.518963
# Epoch 394/400 - Elapsed Time 2167.861641 - Remaining Time 33.013121
# Epoch 395/400 - Elapsed Time 2172.961809 - Remaining Time 27.505846
# Epoch 396/400 - Elapsed Time 2178.477290 - Remaining Time 22.004821
# Epoch 397/400 - Elapsed Time 2184.320599 - Remaining Time 16.506201
# Epoch 398/400 - Elapsed Time 2189.435911 - Remaining Time 11.002191
# Epoch 399/400 - Elapsed Time 2194.558267 - Remaining Time 5.500146
# Epoch 400/400 - Elapsed Time 2199.797383 - Remaining Time 0.000000

# %% [markdown]
# The next block will run prediction on the test set and save the output detections

# %%
from __future__ import division
from __future__ import print_function

import numpy as np
import torch
from torch.utils.data import DataLoader
from torchvision import transforms

from hourglass import hg

from dataset import Dataset
from dataset import CropAndPad, LocsToHeatmaps, ToTensor, Normalize
from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = hg(num_stacks=1, num_blocks=1, num_classes=10).to(device)
checkpoint = torch.load('/content/gdrive/My Drive/cis580-2019-hw6/model_checkpoint.pt')
model.load_state_dict(checkpoint['model'])
transform_list = [CropAndPad(out_size=(256, 256))]
transform_list.append(LocsToHeatmaps(out_size=(64,64)))
transform_list.append(ToTensor())
transform_list.append(Normalize())
test_ds = Dataset(is_train=False, transform=transforms.Compose(transform_list))
data_loader = DataLoader(test_ds, batch_size=1, pin_memory=True, shuffle=False)
predicted_heatmaps = np.zeros((len(test_ds), 10, 64, 64))
for i, batch in enumerate(tqdm(data_loader)):
    model.eval()
    images = batch['image'].to(device)
    with torch.no_grad():
        pred_heatmap_list = model(images)
    pred_heatmaps = pred_heatmap_list[-1]
    predicted_heatmaps[i,:,:,:] = pred_heatmaps[0,:,:,:].cpu().numpy()
np.save('/content/gdrive/My Drive/cis580-2019-hw6/detections.npy', predicted_heatmaps)
# Out:
# 100%|██████████| 27/27 [00:00<00:00, 31.70it/s]

# %% [markdown]
# Import the external and given functions for step 2

# %%
import numpy as np
import torch
import torch.nn as nn
import cv2
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import os
from os.path import join
from utils import plot_mesh

"""
Convert axis-angle representation to a 3x3 rotation matrix
"""
class Rodrigues(torch.autograd.Function):
    @staticmethod
    def forward(self, inp):
        pose = inp.detach().cpu().numpy()
        rotm, part_jacob = cv2.Rodrigues(pose)
        self.jacob = torch.Tensor(np.transpose(part_jacob)).contiguous()
        rotation_matrix = torch.Tensor(rotm.ravel())
        return rotation_matrix.view(3,3)

    @staticmethod
    def backward(self, grad_output):
        grad_output = grad_output.view(1,-1)
        grad_input = torch.mm(grad_output, self.jacob)
        grad_input = grad_input.view(-1)
        return grad_input
"""
This is the function you should call to convert fom axis-angle to a rotation matrix
Example usage:
    aa = torch.zeros(3)
    R = rodrigues(aa)
"""
rodrigues = Rodrigues.apply

# %% [markdown]
# Step 2) Implement pose_optimization and heatmaps_to_locs as specified by the accompanying PDF

# %%
"""
YOU NEED TO IMPLEMENT THIS
Input: image, mesh vertices, mesh faces, detected 2d keypoints, keypoint confidences, 3D keypoint coordinates in the canonical position, intrinsic camera matrix
Output: R, t
"""
def pose_optimization(img, vertices, faces, keypoints_2d, conf, keypoints_3d, K):
    # Send variables to GPU
    device = keypoints_2d.device
    keypoints_3d = keypoints_3d.to(device)
    K = K.to(device)
    r = torch.rand(3, requires_grad=True, device=device) # rotation in axis-angle representation
    t = torch.rand(3 ,requires_grad=True, device=device)
    d = conf.sqrt()[:, None]
    # 2D keypoints in normalized coordinates
    norm_keypoints_2d = torch.matmul(K.inverse(), torch.cat((keypoints_2d, torch.ones(keypoints_2d.shape[0],1, device=device)), dim=-1).t()).t()[:,:-1]
    # set up optimizer
    optimizer = torch.optim.Adam([r,t], lr=1e-2)
    # converge check
    converged = False
    rel_tol = 1e-5
    loss_old = 100
    while not converged:
      optimizer.zero_grad()
      # convert axis-angle to rotation matrix
      R = rodrigues(r)
      # 1) Compute projected keypoints based on current estimate of R and t
      im_pts = keypoints_3d.transpose(1, 0)
      pts_w = torch.matmul(R, im_pts) + t[:, None]
      norm_pts = pts_w / pts_w[2]
      
      proj_keypoints = (norm_pts).transpose(1,0) 
      # 2) Compute error (based on distance between projected keypoints and detected keypoints)
      diff = norm_keypoints_2d - proj_keypoints[:, :2] # confidance & err
      error = torch.sum(((diff)*d)**2)
      # 3) Update based on error
      error.backward()
      optimizer.step()
      # 4) Check for convergence
      if abs(error.detach() - loss_old) / loss_old < rel_tol: # less than threshould converge and break
        break
      else:
        loss_old = error.detach() 
        
      # IMPLEMENT THE ABOVE

    R = rodrigues(r)
    plt.figure()
    plot_mesh(img, vertices, faces, R.detach().cpu().numpy(), t.detach().cpu().numpy()[:,None], K.detach().cpu().numpy())
    pk = torch.matmul(K, proj_keypoints.t()).t()
    pk = pk.detach().cpu().numpy()
    plt.scatter(pk[:,0], pk[:,1], color='r')
    plt.show()
    return rodrigues(r)[0].detach(), t.detach()

"""
YOU NEED TO IMPLEMENT THIS
Convert heatmaps to 2D locations
Input: Nx10x64x64 keypoint heatmaps
Output: Nx10x3 keypoint locations and detection confidence (magnitude of the highest activation)
"""
def heatmaps_to_locs(heatmaps):

    # get keypoints
    r_max = torch.max(heatmaps,-2)   
    c_max = torch.max(heatmaps,-1)  
    
    # get maxinum pts' locs
    r_ind = torch.argmax(c_max[0],-1).unsqueeze(-1)
    c_ind = torch.argmax(r_max[0],-1).unsqueeze(-1)
    Loc = torch.cat([c_ind,r_ind],dim=-1).float()
    
    # get their confidence
    confidence = torch.max(c_max[0],-1)[0].float().unsqueeze(-1)  
    key_loc = torch.cat([Loc,confidence],dim=-1)
    
    return key_loc

# %% [markdown]
# The next block will start the pose optimization process. Be sure to run the above block first every time you want to test changes to the code.

# %%
data = np.load('data/misc_data.npz')
K = torch.from_numpy(data['K']).float()
S = torch.from_numpy(np.load('data/kpt.npy'))
vertices = data['vertices']
faces = data['faces']

dataset = np.load('data/valid_data.npz')
imgnames = dataset['imgname']
scales = torch.from_numpy(dataset['scale']).float()[:,None]
centers = torch.from_numpy(dataset['center']).float()
# detections.npy contains the detections saved after training your model and running predict.py
heatmaps = torch.from_numpy(np.load('/content/gdrive/My Drive/cis580-2019-hw6/detections.npy'))

keypoint_locs = heatmaps_to_locs(heatmaps)

# Compute detected 2D keypoint locations in the original image
ul_corner = centers - scales * 100
keypoint_locs[:,:,:-1] *= scales[:,:,None]*200 / 64
keypoint_locs[:,:,:-1] += ul_corner[:,None,:]

images = np.load('data/images.npz')

os.makedirs('/content/gdrive/My Drive/cis580-2019-hw6/pose_optimization', exist_ok=True)
for i in range(len(heatmaps)):
    img_name = imgnames[i].decode('utf-8')
    print("Processing ", img_name)
    img = images[img_name]
    pose_optimization(img, vertices, faces, keypoint_locs[i,:,:-1], keypoint_locs[i,:,-1], S, K)
    plt.savefig('/content/gdrive/My Drive/cis580-2019-hw6/pose_optimization/%s' % img_name, dpi=300)
    plt.close('all')
# Out:
# Processing  train_148.jpg
# Processing  train_160.jpg
# Processing  train_80.jpg
# Processing  train_181.jpg
# Processing  train_176.jpg
# Processing  train_2.jpg
# Processing  train_155.jpg
# Processing  train_136.jpg
# Processing  train_4.jpg
# Processing  train_18.jpg
# Processing  train_106.jpg
# Processing  train_90.jpg
# Processing  train_25.jpg
# Processing  train_116.jpg
# Processing  train_190.jpg
# Processing  train_177.jpg
# Processing  train_52.jpg
# Processing  train_191.jpg
# Processing  train_13.jpg
# Processing  train_9.jpg
# Processing  train_81.jpg
# Processing  train_21.jpg
# Processing  train_72.jpg
# Processing  train_144.jpg
# Processing  train_10.jpg
# Processing  train_12.jpg
# Processing  train_140.jpg
